# %% [markdown]
# # HIVCare AI — Model Training (Google Colab)
#
# Upload your Kaggle CSV or use synthetic data. Download `artifacts/model.pkl` for deployment.

# %%
# !pip install -q pandas numpy scikit-learn imbalanced-learn shap matplotlib seaborn joblib
# Optional: !pip install -q tensorflow

# %%
from google.colab import files
# uploaded = files.upload()  # upload hiv_dataset.csv
# !mv hiv_dataset.csv data/hiv_dataset.csv

# %%
# %cd /content
# Clone or upload project ml/ folder, then:
# !python train.py
# With CSV: !python train.py --csv data/hiv_dataset.csv

# %%
from google.colab import files
files.download('artifacts/model.pkl')
files.download('artifacts/metrics.json')
